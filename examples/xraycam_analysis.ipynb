# %%
# Initialize stuff
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
import numpy as np

from xraycam import camcontrol

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# Reprocess 'long4' data from last time
prefixes = ['data/4.29.real%d' % i for i in range(36, 46)]
rset = camcontrol.RunSet(prefixes = prefixes)
reduced_frame = rset.filter_reduce_frames(threshold_min = 40, threshold_max = 100)

# %%
reduced_frame.show(vmin = 0, vmax = 70, origin = 'nearest')
plt.plot(reduced_frame.lineout(smooth = 2))
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
dataruns = camcontrol.RunSet()

# %%
[dataruns.insert(run_prefix='data/5.4.run%s' % i, gain = '0x3f',
        numExposures = 400, run = False) for i in [5, 7, 8, 9]]
# Out:
# [None, None, None, None]

# %%
lineouts = dataruns.plot_lineouts(filter = True, smooth = 2,
                           threshold_min = 32, threshold_max = 100)
# Out:
# <img src="data:image/png;base64,...">

# %%
import importlib
importlib.reload(camcontrol)
# Out:
# <module 'xraycam.camcontrol' from '/home/oliver/.local/lib/python3.5/site-packages/xraycam-0.0.0-py3.5.egg/xraycam/camcontrol.py'>

# %%
# %connect_info
# Out:
# {
#   "shell_port": 38175,
#   "iopub_port": 42555,
#   "stdin_port": 35102,
#   "kernel_name": "",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "ip": "127.0.0.1",
#   "control_port": 54802,
#   "key": "9e86b716-c09b-40b1-8fb0-72f0b0783d0f",
#   "hb_port": 56383
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing /run/user/1001/jupyter/kernel-411c4561-4c37-4e5f-887e-cb8f8268df87.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.
