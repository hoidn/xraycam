# %%
# %matplotlib notebook
from xraycam.declustering import do_decluster
import numpy as np
import matplotlib.pyplot as plt

# %%
size = 40
def test_array():
    testarr = np.random.rand(size, size)
    testarr[testarr < 0.9] = 0
    testarr -= 0.7
    testarr[testarr < 0] = 0
    testarr[testarr > 0] = 20
    testarr *= 100
    testarr = testarr.astype('uint8')
    testarr[:, size/2:] = 0
    return testarr

# %%
def minimal_case():
    arr = np.zeros((5, 10), dtype = 'uint8')
    arr[2, 2] = 20
    arr[3, 2] = 20
    return arr

# %%
def decluster_compare(genfunc = test_array, threshold = 5):
    fig, axes = plt.subplots(2, figsize = (12, 12))
    testarr = genfunc()
    plt.imshow(testarr, interpolation='none')
    dec = do_decluster(testarr, 5)

    for ax, arr in zip(axes, [testarr, dec]):
        im = ax.imshow(arr, interpolation = 'none')

# %%
decluster_compare(minimal_case)
# Out:
# <img src="data:image/png;base64,...">

# %%
decluster_compare()
# Out:
# <img src="data:image/png;base64,...">
# /home/oliver/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:10: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
