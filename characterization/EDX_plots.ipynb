# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
#from utils.mpl_plotly import plt

# %%
import numpy as np

# %%
def plot_fromfile(path):
    dat = np.loadtxt(path)
    plt.plot(*dat.T)

# %%
plot_fromfile('imx291_tube_spectrum_6keV_320uA_gain_213.txt')
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_fromfile('imx291_Cu_K_gain_100.txt')
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_fromfile('imx291_Fe_K_gain_100.txt')
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_fromfile('imx291_Ti_K_gain_150.txt')
# Out:
# <img src="data:image/png;base64,...">
